# %%
docs = """
Exploring the Wonders of Space
What are black holes, and why are they significant?
Black holes are regions in space where gravity is so strong that nothing, not even light, can escape.
They are significant because they help scientists understand the limits of physics, particularly how gravity interacts with spacetime.
How do stars influence the universe?
Stars are the building blocks of galaxies.
They produce light and heat through nuclear fusion, creating elements essential for life.
Stars also play a role in forming planets and distributing energy throughout the universe.
What is the importance of space exploration?
Space exploration expands our knowledge of the universe and helps develop new technologies.
It inspires innovation, provides a better understanding of Earth’s place in the cosmos, and may someday enable humanity to inhabit other planets.
How are scientists searching for life beyond Earth?
Scientists use telescopes to analyze exoplanets' atmospheres and look for conditions that could support life.
Missions like the James Webb Space Telescope and Mars rovers aim to uncover signs of water, organic molecules, or microbial life.
What role do humans have in shaping the future of space?
Human efforts in space exploration, like building space stations and planning missions to Mars, will pave the way for interplanetary travel.
Innovations inspired by space research may lead to sustainable solutions on Earth and beyond.
Can ordinary people contribute to space science?
Yes, through initiatives like citizen science projects, people can help analyze astronomical data, identify celestial phenomena, and support space missions. These collaborations make space exploration more inclusive and impactful.
Where can we learn more about the universe?
Many organizations, like NASA, ESA, and local astronomy clubs, provide free resources and events.
Online platforms like YouTube and educational websites are also excellent places to deepen your knowledge.
Hello k xa khaber.
K gardai xaau timi.
kasto bhai ra xa pada.
Khana khanu bha ko.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Initialize the tokenizer to convert text into numerical sequences
tokenizer = Tokenizer()

# %%
# Fit the tokenizer on the given text to build the vocabulary and word index
tokenizer.fit_on_texts([docs])

# %%
tokenizer.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'space': 3,
#  'of': 4,
#  'are': 5,
#  'to': 6,
#  'in': 7,
#  'like': 8,
#  'they': 9,
#  'can': 10,
#  'universe': 11,
#  'for': 12,
#  'life': 13,
#  'exploration': 14,
#  'what': 15,
#  'scientists': 16,
#  'how': 17,
#  'stars': 18,
#  'missions': 19,
#  'black': 20,
#  'holes': 21,
#  'significant': 22,
#  'where': 23,
#  'gravity': 24,
#  'is': 25,
#  'that': 26,
#  'light': 27,
#  'help': 28,
#  'do': 29,
#  'building': 30,
#  'through': 31,
#  'also': 32,
#  'a': 33,
#  'role': 34,
#  'planets': 35,
#  'knowledge': 36,
#  'may': 37,
#  'beyond': 38,
#  'earth': 39,
#  'analyze': 40,
#  'support': 41,
#  'mars': 42,
#  'people': 43,
#  'science': 44,
#  'more': 45,
#  'k': 46,
#  'xa': 47,
#  'exploring': 48,
#  'wonders': 49,
#  'why': 50,
#  'regions': 51,
#  'so': 52,
#  'strong': 53,
#  'nothing': 54,
#  'not': 55,
#  'even': 56,
#  'escape': 57,
#  'because': 58,
#  'understand': 59,
#  'limits': 60,
#  'physics': 61,
#  'particularly': 62,
#  'interacts': 63,
#  'with': 64,
#  'spacetime': 65,
#  'influence': 66,
#  'blocks': 67,
#  'galaxies': 68,
#  'produce': 69,
#  'heat': 70,
#  'nuclear': 71,
#  'fusion': 72,
#  'creating': 73,
#  'elements': 74,
#  'essential': 75,
#  'play': 76,
#  'forming': 77,
#  'distributing': 78,
#  'energy': 79,
#  'throughout': 80,
#  'importance': 81,
#  'expands': 82,
#  'our': 83,
#  'helps': 84,
#  'develop': 85,
#  'new': 86,
#  'technologies': 87,
#  'it': 88,
#  'inspires': 89,
#  'innovation': 90,
#  'provides': 91,
#  'better': 92,
#  'understanding': 93,
#  'earth’s': 94,
#  'place': 95,
#  'cosmos': 96,
#  'someday': 97,
#  'enable': 98,
#  'humanity': 99,
#  'inhabit': 100,
#  'other': 101,
#  'searching': 102,
#  'use': 103,
#  'telescopes': 104,
#  "exoplanets'": 105,
#  'atmospheres': 106,
#  'look': 107,
#  'conditions': 108,
#  'could': 109,
#  'james': 110,
#  'webb': 111,
#  'telescope': 112,
#  'rovers': 113,
#  'aim': 114,
#  'uncover': 115,
#  'signs': 116,
#  'water': 117,
#  'organic': 118,
#  'molecules': 119,
#  'or': 120,
#  'microbial': 121,
#  'humans': 122,
#  'have': 123,
#  'shaping': 124,
#  'future': 125,
#  'human': 126,
#  'efforts': 127,
#  'stations': 128,
#  'planning': 129,
#  'will': 130,
#  'pave': 131,
#  'way': 132,
#  'interplanetary': 133,
#  'travel': 134,
#  'innovations': 135,
#  'inspired': 136,
#  'by': 137,
#  'research': 138,
#  'lead': 139,
#  'sustainable': 140,
#  'solutions': 141,
#  'on': 142,
#  'ordinary': 143,
#  'contribute': 144,
#  'yes': 145,
#  'initiatives': 146,
#  'citizen': 147,
#  'projects': 148,
#  'astronomical': 149,
#  'data': 150,
#  'identify': 151,
#  'celestial': 152,
#  'phenomena': 153,
#  'these': 154,
#  'collaborations': 155,
#  'make': 156,
#  'inclusive': 157,
#  'impactful': 158,
#  'we': 159,
#  'learn': 160,
#  'about': 161,
#  'many': 162,
#  'organizations': 163,
#  'nasa': 164,
#  'esa': 165,
#  'local': 166,
#  'astronomy': 167,
#  'clubs': 168,
#  'provide': 169,
#  'free': 170,
#  'resources': 171,
#  'events': 172,
#  'online': 173,
#  'platforms': 174,
#  'youtube': 175,
#  'educational': 176,
#  'websites': 177,
#  'excellent': 178,
#  'places': 179,
#  'deepen': 180,
#  'your': 181,
#  'hello': 182,
#  'khaber': 183,
#  'gardai': 184,
#  'xaau': 185,
#  'timi': 186,
#  'kasto': 187,
#  'bhai': 188,
#  'ra': 189,
#  'pada': 190,
#  'khana': 191,
#  'khanu': 192,
#  'bha': 193,
#  'ko': 194}

# %%
len(tokenizer.word_index)
# Out:
# 194

# %%
# Initialize a list to store the generated input sequences
input_sequences = []
# Split the text into individual sentences by newline characters
for sentence in docs.split('\n'):
    # Convert the current sentence into a sequence of integers based on the tokenizer
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    # print(tokenized_sentence)

    # Create multiple subsequences from the tokenized sentence
    # For each word in the sentence (after the first one), append the sequence from the start to the current word
    for i in range(1, len(tokenized_sentence)):
        input_sequences.append(tokenized_sentence[:i + 1])  # Add the current subsequence to the list

# %%
input_sequences
# Out:
# [[48, 2],
#  [48, 2, 49],
#  [48, 2, 49, 4],
#  [48, 2, 49, 4, 3],
#  [15, 5],
#  [15, 5, 20],
#  [15, 5, 20, 21],
#  [15, 5, 20, 21, 1],
#  [15, 5, 20, 21, 1, 50],
#  [15, 5, 20, 21, 1, 50, 5],
#  [15, 5, 20, 21, 1, 50, 5, 9],
#  [15, 5, 20, 21, 1, 50, 5, 9, 22],
#  [20, 21],
#  [20, 21, 5],
#  [20, 21, 5, 51],
#  [20, 21, 5, 51, 7],
#  [20, 21, 5, 51, 7, 3],
#  [20, 21, 5, 51, 7, 3, 23],
#  [20, 21, 5, 51, 7, 3, 23, 24],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54, 55],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54, 55, 56],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54, 55, 56, 27],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54, 55, 56, 27, 10],
#  [20, 21, 5, 51, 7, 3, 23, 24, 25, 52, 53, 26, 54, 55, 56, 27, 10, 57],
#  [9, 5],
#  [9, 5, 22],
#  [9, 5, 22, 58],
#  [9, 5, 22, 58, 9],
#  [9, 5, 22, 58, 9, 28],
#  [9, 5, 22, 58, 9, 28, 16],
#  [9, 5, 22, 58, 9, 28, 16, 59],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62, 17],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62, 17, 24],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62, 17, 24, 63],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62, 17, 24, 63, 64],
#  [9, 5, 22, 58, 9, 28, 16, 59, 2, 60, 4, 61, 62, 17, 24, 63, 64, 65],
#  [17, 29],
#  [17, 29, 18],
#  [17, 29, 18, 66],
#  [17, 29, 18, 66, 2],
#  [17, 29, 18, 66, 2, 11],
#  [18, 5],
#  [18, 5, 2],
#  [18, 5, 2, 30],
#  [18, 5, 2, 30, 67],
#  [18, 5, 2, 30, 67, 4],
#  [18, 5, 2, 30, 67, 4, 68],
#  [9, 69],
#  [9, 69, 27],
#  [9, 69, 27, 1],
#  [9, 69, 27, 1, 70],
#  [9, 69, 27, 1, 70, 31],
#  [9, 69, 27, 1, 70, 31, 71],
#  [9, 69, 27, 1, 70, 31, 71, 72],
#  [9, 69, 27, 1, 70, 31, 71, 72, 73],
#  [9, 69, 27, 1, 70, 31, 71, 72, 73, 74],
#  [9, 69, 27, 1, 70, 31, 71, 72, 73, 74, 75],
#  [9, 69, 27, 1, 70, 31, 71, 72, 73, 74, 75, 12],
#  [9, 69, 27, 1, 70, 31, 71, 72, 73, 74, 75, 12, 13],
#  [18, 32],
#  [18, 32, 76],
#  [18, 32, 76, 33],
#  [18, 32, 76, 33, 34],
#  [18, 32, 76, 33, 34, 7],
#  [18, 32, 76, 33, 34, 7, 77],
#  [18, 32, 76, 33, 34, 7, 77, 35],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1, 78],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1, 78, 79],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1, 78, 79, 80],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1, 78, 79, 80, 2],
#  [18, 32, 76, 33, 34, 7, 77, 35, 1, 78, 79, 80, 2, 11],
#  [15, 25],
#  [15, 25, 2],
#  [15, 25, 2, 81],
#  [15, 25, 2, 81, 4],
#  [15, 25, 2, 81, 4, 3],
#  [15, 25, 2, 81, 4, 3, 14],
#  [3, 14],
#  [3, 14, 82],
#  [3, 14, 82, 83],
#  [3, 14, 82, 83, 36],
#  [3, 14, 82, 83, 36, 4],
#  [3, 14, 82, 83, 36, 4, 2],
#  [3, 14, 82, 83, 36, 4, 2, 11],
#  [3, 14, 82, 83, 36, 4, 2, 11, 1],
#  [3, 14, 82, 83, 36, 4, 2, 11, 1, 84],
#  [3, 14, 82, 83, 36, 4, 2, 11, 1, 84, 85],
#  [3, 14, 82, 83, 36, 4, 2, 11, 1, 84, 85, 86],
#  [3, 14, 82, 83, 36, 4, 2, 11, 1, 84, 85, 86, 87],
#  [88, 89],
#  [88, 89, 90],
#  [88, 89, 90, 91],
#  [88, 89, 90, 91, 33],
#  [88, 89, 90, 91, 33, 92],
#  [88, 89, 90, 91, 33, 92, 93],
#  [88, 89, 90, 91, 33, 92, 93, 4],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37, 97],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37, 97, 98],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37, 97, 98, 99],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37, 97, 98, 99, 6],
#  [88, 89, 90, 91, 33, 92, 93, 4, 94, 95, 7, 2, 96, 1, 37, 97, 98, 99, 6, 100],
#  [88,
#   89,
#   90,
#   91,
#   33,
#   92,
#   93,
#   4,
#   94,
#   95,
#   7,
#   2,
#   96,
#   1,
#   37,
#   97,
#   98,
#   99,
#   6,
#   100,
#   101],
#  [88,
#   89,
#   90,
#   91,
#   33,
#   92,
#   93,
#   4,
#   94,
#   95,
#   7,
#   2,
#   96,
#   1,
#   37,
#   97,
#   98,
#   99,
#   6,
#   100,
#   101,
#   35],
#  [17, 5],
#  [17, 5, 16],
#  [17, 5, 16, 102],
#  [17, 5, 16, 102, 12],
#  [17, 5, 16, 102, 12, 13],
#  [17, 5, 16, 102, 12, 13, 38],
#  [17, 5, 16, 102, 12, 13, 38, 39],
#  [16, 103],
#  [16, 103, 104],
#  [16, 103, 104, 6],
#  [16, 103, 104, 6, 40],
#  [16, 103, 104, 6, 40, 105],
#  [16, 103, 104, 6, 40, 105, 106],
#  [16, 103, 104, 6, 40, 105, 106, 1],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12, 108],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12, 108, 26],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12, 108, 26, 109],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12, 108, 26, 109, 41],
#  [16, 103, 104, 6, 40, 105, 106, 1, 107, 12, 108, 26, 109, 41, 13],
#  [19, 8],
#  [19, 8, 2],
#  [19, 8, 2, 110],
#  [19, 8, 2, 110, 111],
#  [19, 8, 2, 110, 111, 3],
#  [19, 8, 2, 110, 111, 3, 112],
#  [19, 8, 2, 110, 111, 3, 112, 1],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115, 116],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115, 116, 4],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115, 116, 4, 117],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115, 116, 4, 117, 118],
#  [19, 8, 2, 110, 111, 3, 112, 1, 42, 113, 114, 6, 115, 116, 4, 117, 118, 119],
#  [19,
#   8,
#   2,
#   110,
#   111,
#   3,
#   112,
#   1,
#   42,
#   113,
#   114,
#   6,
#   115,
#   116,
#   4,
#   117,
#   118,
#   119,
#   120],
#  [19,
#   8,
#   2,
#   110,
#   111,
#   3,
#   112,
#   1,
#   42,
#   113,
#   114,
#   6,
#   115,
#   116,
#   4,
#   117,
#   118,
#   119,
#   120,
#   121],
#  [19,
#   8,
#   2,
#   110,
#   111,
#   3,
#   112,
#   1,
#   42,
#   113,
#   114,
#   6,
#   115,
#   116,
#   4,
#   117,
#   118,
#   119,
#   120,
#   121,
#   13],
#  [15, 34],
#  [15, 34, 29],
#  [15, 34, 29, 122],
#  [15, 34, 29, 122, 123],
#  [15, 34, 29, 122, 123, 7],
#  [15, 34, 29, 122, 123, 7, 124],
#  [15, 34, 29, 122, 123, 7, 124, 2],
#  [15, 34, 29, 122, 123, 7, 124, 2, 125],
#  [15, 34, 29, 122, 123, 7, 124, 2, 125, 4],
#  [15, 34, 29, 122, 123, 7, 124, 2, 125, 4, 3],
#  [126, 127],
#  [126, 127, 7],
#  [126, 127, 7, 3],
#  [126, 127, 7, 3, 14],
#  [126, 127, 7, 3, 14, 8],
#  [126, 127, 7, 3, 14, 8, 30],
#  [126, 127, 7, 3, 14, 8, 30, 3],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42, 130],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42, 130, 131],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42, 130, 131, 2],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42, 130, 131, 2, 132],
#  [126, 127, 7, 3, 14, 8, 30, 3, 128, 1, 129, 19, 6, 42, 130, 131, 2, 132, 12],
#  [126,
#   127,
#   7,
#   3,
#   14,
#   8,
#   30,
#   3,
#   128,
#   1,
#   129,
#   19,
#   6,
#   42,
#   130,
#   131,
#   2,
#   132,
#   12,
#   133],
#  [126,
#   127,
#   7,
#   3,
#   14,
#   8,
#   30,
#   3,
#   128,
#   1,
#   129,
#   19,
#   6,
#   42,
#   130,
#   131,
#   2,
#   132,
#   12,
#   133,
#   134],
#  [135, 136],
#  [135, 136, 137],
#  [135, 136, 137, 3],
#  [135, 136, 137, 3, 138],
#  [135, 136, 137, 3, 138, 37],
#  [135, 136, 137, 3, 138, 37, 139],
#  [135, 136, 137, 3, 138, 37, 139, 6],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140, 141],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140, 141, 142],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140, 141, 142, 39],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140, 141, 142, 39, 1],
#  [135, 136, 137, 3, 138, 37, 139, 6, 140, 141, 142, 39, 1, 38],
#  [10, 143],
#  [10, 143, 43],
#  [10, 143, 43, 144],
#  [10, 143, 43, 144, 6],
#  [10, 143, 43, 144, 6, 3],
#  [10, 143, 43, 144, 6, 3, 44],
#  [145, 31],
#  [145, 31, 146],
#  [145, 31, 146, 8],
#  [145, 31, 146, 8, 147],
#  [145, 31, 146, 8, 147, 44],
#  [145, 31, 146, 8, 147, 44, 148],
#  [145, 31, 146, 8, 147, 44, 148, 43],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149, 150],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149, 150, 151],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149, 150, 151, 152],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149, 150, 151, 152, 153],
#  [145, 31, 146, 8, 147, 44, 148, 43, 10, 28, 40, 149, 150, 151, 152, 153, 1],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3,
#   14],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3,
#   14,
#   45],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3,
#   14,
#   45,
#   157],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3,
#   14,
#   45,
#   157,
#   1],
#  [145,
#   31,
#   146,
#   8,
#   147,
#   44,
#   148,
#   43,
#   10,
#   28,
#   40,
#   149,
#   150,
#   151,
#   152,
#   153,
#   1,
#   41,
#   3,
#   19,
#   154,
#   155,
#   156,
#   3,
#   14,
#   45,
#   157,
#   1,
#   158],
#  [23, 10],
#  [23, 10, 159],
#  [23, 10, 159, 160],
#  [23, 10, 159, 160, 45],
#  [23, 10, 159, 160, 45, 161],
#  [23, 10, 159, 160, 45, 161, 2],
#  [23, 10, 159, 160, 45, 161, 2, 11],
#  [162, 163],
#  [162, 163, 8],
#  [162, 163, 8, 164],
#  [162, 163, 8, 164, 165],
#  [162, 163, 8, 164, 165, 1],
#  [162, 163, 8, 164, 165, 1, 166],
#  [162, 163, 8, 164, 165, 1, 166, 167],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168, 169],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168, 169, 170],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168, 169, 170, 171],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168, 169, 170, 171, 1],
#  [162, 163, 8, 164, 165, 1, 166, 167, 168, 169, 170, 171, 1, 172],
#  [173, 174],
#  [173, 174, 8],
#  [173, 174, 8, 175],
#  [173, 174, 8, 175, 1],
#  [173, 174, 8, 175, 1, 176],
#  [173, 174, 8, 175, 1, 176, 177],
#  [173, 174, 8, 175, 1, 176, 177, 5],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178, 179],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178, 179, 6],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178, 179, 6, 180],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178, 179, 6, 180, 181],
#  [173, 174, 8, 175, 1, 176, 177, 5, 32, 178, 179, 6, 180, 181, 36],
#  [182, 46],
#  [182, 46, 47],
#  [182, 46, 47, 183],
#  [46, 184],
#  [46, 184, 185],
#  [46, 184, 185, 186],
#  [187, 188],
#  [187, 188, 189],
#  [187, 188, 189, 47],
#  [187, 188, 189, 47, 190],
#  [191, 192],
#  [191, 192, 193],
#  [191, 192, 193, 194]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
max_len
# Out:
# 29

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Pad the input sequences to ensure all sequences have the same length
# maxlen specifies the fixed length for all sequences; padding='pre' adds zeros at the beginning
padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  48,   2],
#        [  0,   0,   0, ...,  48,   2,  49],
#        [  0,   0,   0, ...,   2,  49,   4],
#        ...,
#        [  0,   0,   0, ...,   0, 191, 192],
#        [  0,   0,   0, ..., 191, 192, 193],
#        [  0,   0,   0, ..., 192, 193, 194]], dtype=int32)

# %%
# Separate the input (X) and output (y) from the padded sequences
# X contains all tokens except the last one in each sequence
X = padded_input_sequences[:,:-1]

# %%
# y contains only the last token in each sequence (the target output)
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (286, 28)

# %%
# Example: If X.shape is (num_samples, sequence_length)
# X = X.reshape((X.shape[0], X.shape[1], 1))  # Reshape to 3D with 1 feature per timestep

# %%
X.shape
# Out:
# (286, 28)

# %%
y.shape
# Out:
# (286,)

# %%
from tensorflow.keras.utils import to_categorical
# Convert the target output (y) into one-hot encoded format
# This is needed for multi-class classification with a categorical output
y = to_categorical(y,num_classes=195)

# %%
y.shape
# Out:
# (286, 195)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Initialize a sequential model
model = Sequential()
# Add an embedding layer to convert input tokens into dense vector representations
# - 180: Vocabulary size (number of unique words)
# - 100: Dimension of the dense vector for each word (embedding size)
# - input_length=28: Length of each input sequence
model.add(Embedding(195, 100, input_length=28))
# Add the first LSTM layer with 150 units to process sequential data
model.add(LSTM(150))

# Add a Dense (fully connected) layer with 180 units
# - Softmax activation is used to predict probabilities for 180 possible outputs
model.add(Dense(195, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile the model
# - loss='categorical_crossentropy': Suitable for multi-class classification
# - optimizer='adam': Adaptive optimizer for efficient learning
# - metrics=['accuracy']: Track accuracy during training
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
# model.summary()

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.0170 - loss: 5.2723
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.0381 - loss: 5.2182
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.0522 - loss: 5.0135
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0486 - loss: 4.9666
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.0476 - loss: 4.9228
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.0673 - loss: 4.9031
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.0612 - loss: 4.7233
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0736 - loss: 4.8212
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0676 - loss: 4.6405
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.0814 - loss: 4.5925
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.0829 - loss: 4.4950
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.0622 - loss: 4.4013
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0729 - loss: 4.3746
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.0726 - loss: 4.2553
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.0884 - loss: 4.2199
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.0793 - loss: 4.1787
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.1020 - loss: 4.0203
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1110 - loss: 3.9319
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.1451 - loss: 3.7834
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.1527 - loss: 3.7841
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.1852 - loss: 3.5881
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.2022 - loss: 3.4932
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2121 - loss: 3.3442
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2378 - loss: 3.2496
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.2935 - loss: 3.0661
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.2947 - loss: 3.0763
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.3637 - loss: 2.8903
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.3882 - loss: 2.7475
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3912 - loss: 2.6540
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.4148 - loss: 2.5046
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.4749 - loss: 2.4383
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5320 - loss: 2.3125
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.5258 - loss: 2.1711
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6030 - loss: 2.0509
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6191 - loss: 2.0245
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.6538 - loss: 1.8691
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7038 - loss: 1.7912
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.7418 - loss: 1.6827
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7534 - loss: 1.6464
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7983 - loss: 1.5405
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8231 - loss: 1.4430
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8382 - loss: 1.3749
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8775 - loss: 1.3002
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8866 - loss: 1.2444
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8723 - loss: 1.2165
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8831 - loss: 1.1663
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8920 - loss: 1.1626
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9087 - loss: 1.0736
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9236 - loss: 0.9891
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9385 - loss: 0.9786
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9370 - loss: 0.9537
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9415 - loss: 0.8706
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9469 - loss: 0.8474
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9649 - loss: 0.7971
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9625 - loss: 0.7256
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9694 - loss: 0.7223
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9746 - loss: 0.7624
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9849 - loss: 0.6785
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9825 - loss: 0.6518
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9774 - loss: 0.6219
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9827 - loss: 0.5803
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9868 - loss: 0.5571
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9835 - loss: 0.5561
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9776 - loss: 0.5188
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9822 - loss: 0.4587
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9789 - loss: 0.4828
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9807 - loss: 0.4457
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9835 - loss: 0.4366
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9852 - loss: 0.4167
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9939 - loss: 0.3939
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9903 - loss: 0.3752
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9798 - loss: 0.3717
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9715 - loss: 0.3740
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9846 - loss: 0.3559
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9785 - loss: 0.3369
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9736 - loss: 0.3161
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9863 - loss: 0.2957
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9839 - loss: 0.2977
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9751 - loss: 0.3101
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9791 - loss: 0.2914
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9833 - loss: 0.2537
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9885 - loss: 0.2564
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9861 - loss: 0.2389
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9718 - loss: 0.2496
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9790 - loss: 0.2361
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9867 - loss: 0.2185
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9807 - loss: 0.2302
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9847 - loss: 0.2029
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9832 - loss: 0.2126
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9833 - loss: 0.2092
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9795 - loss: 0.2145
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9856 - loss: 0.1927
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9840 - loss: 0.1870
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9828 - loss: 0.1814
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9844 - loss: 0.1817
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9881 - loss: 0.1679
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9789 - loss: 0.1771
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9800 - loss: 0.1554
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9746 - loss: 0.1640
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9810 - loss: 0.1683

# %%
model.save('/content/drive/MyDrive/workshop_program/code_notebook/trained_models/next_word_predictor.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/workshop_program/code_notebook/trained_models/next_word_predictor.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import numpy as np

# %%
import time
text = "Scientists use"

for i in range(5):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Kasto bhai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Kasto bhai ra
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Kasto bhai ra xa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Kasto bhai ra xa pada
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Kasto bhai ra xa pada pada
